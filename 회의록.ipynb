# %% [markdown]
# # 서울 시민 데이터를 활용한 도시문제 해결
#
#
# > 사전 참고 자료
#
# 1. 서울특별시 빅데이터 캠퍼스: https://bigdata.seoul.go.kr/main.do
# 2. 서울 열린데이터광장: https://data.seoul.go.kr/
# 3. 서울 연구데이터서비스: https://data.si.re.kr/data
# 4. 공공데이터포털: https://www.data.go.kr/
# 5. 제 1회 서울 데이터 행정 포럼: https://www.youtube.com/watch?v=be58PcoBNn0
# 6. 공공데이터 활용 우수 사례: https://www.data.go.kr/tcs/eds/ctm/selectContestDataList.do
#
#
# ## 0. 실제 사례 예시 (국가 차원에서)
#
# 1. 범죄예측지수, 감시 취약 지수 비교 분석 / CCTV 우선 설치지역 분석
# 2. 버스 노선 개선 및 차량배치 / 교통 취약지역 분석
# 3. 공동 주택 관리비 부당지수 분석 / 관리비 부정, 이상여부 모니터링 - 약간 FDS같음
# 4. 업무 효율 강화, 자동화를 위한 분석
# 5. etc
#
# ---

# %% [markdown]
# ## 1차 회의
#
# ### 1. 주제 선정
#
# - 문제, 해결 / 해결에 필요한 데이터셋
# - 데이터 분석 자체로는 문제 해결이 되는 경우는 없을 것 같고, 해결책에 대한 객관적인 지표 제공, 빠른 해결을 돕는 수단이 될 가능성이 높지 않나 라고 생각
# - 분석을 넘어 모델링까지 가야 해결에 더 가까워지는 것 같다
#
# 1. 서울시민의 업종별 카드소비 패턴 데이터 + 소비품목(통계청)별 상품판매 데이터 + 행정동단위 분기별 추정매출액 / 서울시 소비활동지수를 위한 금융통계 / + 소비자 물가 지수
#     - https://data.si.re.kr/node/286
#     - 서울 시민의 (거시적으로) 돈이 어디로 흐르는지 볼 수 있으면, 경제적 지표에 대한 인사이트를 얻을 수 있지 않은가
#     - 언제 총 거래량 자체가 변화하는가,
#     - 1인당 GDP 의 성장률이 가장 많을 때에 대한 위 분석을 체크 해 보면 ...
#
# 2. **위 소비 데이터를 환경과 묶으면, 사람들의 탄소 배출량에 따라 배출 요인분석 추적이 가능할 수 있다.**
#     - (온도 + 습도) 불쾌지수 ->
#     - 탄소 배출과 관련된 환경 문제 해결을 위해,
#     - 소비와 폐기물(년도 별 데이터가 있음) 제출 -> 쓰레기와 연결 지어서 // 특정 소비 패턴이 어떤, 어떻게 쓰레기를 만드는지
#     - 어떻게 하면 쓰레기 (폐기물)을 줄일 수 있을까, ->
#     - zero waste shop
#
# 3. 외국인 방문 데이터 + 소비 => 외국인 대상 관광지 강화
#     - 외국인 관광객 대상으로 support 해 줄 수 있는 서울시 장치들이 많이 부족하다 (가설)
#     - => 서울 외국인 관광 데이터 누계 줄 세우기,
#
# 4. SNS 혐오표현, 온도와 관계성 (불쾌지수)
#
#
# 5. 크롤링이 가능하다면, SNS + 인터넷 커뮤니티 + 인터넷방송 //
#
#
# 6. 놀이공원, 휴양지, 핫플레이스 놀러가는게 눈치게임 - 놀러가기 최적의 날 예상하기, 한강공원 가기 가장 좋은 시간
#
#
# 7. 혐오 시설 - 쓰레기 소각장, 매립지
#     - 구 단위 가구 정보
#     - 기존 혐오 시설 분포 및 위치 정보
#     - 지반 정보가 중요할 수 있는데 해당 정보는 얻기 어려울 가능성이 높다.
#     -
#
#
# - dumy,
#     - 식량문제? 흉작, 풍작 ,,, 날씨데이터와 누적 데이터 기반으로 풍흉작에 대한 예측이 가능하다면?
#     - 환경 이슈, 탄소관련
#     - 장애인의 대중 교통 접근성을 데이터 분석으로 가장 취약한 곳을 찾아서 실질적 문제점 찾기
#     - 통근 패턴, 전기차 충전기 위치 선정, 골목길 분석 - 안전한 길 (취약 점)
#
#
#
# ### 2. 팀 병합 (완료)
#
#
# ---

# %% [markdown]
# ## 2차 회의
#
#
# ### 0. 사전 준비 주제
#
# - 가
#
# ### 1. 주제 선정 마무리 및 고도화
#
# - 피드백 내용
#
#     ```python
#     안녕하세요, 정현우님! 데이콘 DS팀 정성문입니다.
#
#     보내주신 주제를 정리해드립니다.
#
#     1. 서울 시민 금융 데이터를 활용한 탄소 배출량 및 폐기물 분석 시각화
#     2. 혐오 시설 입지 선정
#
#     보내주신 주제는 모두 환경 문제와 관련이 있는 것 같습니다.
#
#     본 대회의 주제는 서울 시민 데이터를 활용한 도시문제 해결입니다.
#
#     해당 주제의 주안점은 서울시 데이터와 도시문제 해결입니다.
#
#     이를 감안하면 두 주제 모두 적절한 주제인 것으로 보입니다.
#
#     하지만, 1번 주제의 경우 사용하신 데이터(금융 데이터)와 목적(탄소 배출량, 폐기물) 사이에 뚜렷한 인과관계가 있을 지 우려가 됩니다.
#
#     1번 주제의 탄소 배출량, 폐기물 데이터를 이용하여 2번 주제인 혐오 시설의 입지를 선정하는 것이 더 적절해 보입니다.
#
#     아울러, 향후 진행 일정은 추후 공지 예정이며, 특이사항이나 유의사항도 사전에 공지드리도록 하겠습니다.
#
#     감사합니다.
#
#     정성문 드림.
#     ```
#
# - 기피 시설 입지 선정
